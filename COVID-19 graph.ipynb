# %%
import pandas as pd
import numpy as np
import altair as alt
covid = pd.read_excel("COVID-19-geographic-disbtribution-worldwide-2020-09-22.xlsx")
covid
covid_th = covid[covid['countriesAndTerritories'] == 'Thailand']
covid_th
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 39868 2020-09-22   22      9  2020      5       0                Thailand
# 39869 2020-09-21   21      9  2020      0       0                Thailand
# 39870 2020-09-20   20      9  2020      6       0                Thailand
# 39871 2020-09-19   19      9  2020      3       1                Thailand
# 39872 2020-09-18   18      9  2020      7       0                Thailand
# ...          ...  ...    ...   ...    ...     ...                     ...
# 40123 2020-01-04    4      1  2020      0       0                Thailand
# 40124 2020-01-03    3      1  2020      0       0                Thailand
# 40125 2020-01-02    2      1  2020      0       0                Thailand
# 40126 2020-01-01    1      1  2020      0       0                Thailand
# 40127 2019-12-31   31     12  2019      0       0                Thailand
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 39868    TH                  THA   69625581.0         Asia
# 39869    TH                  THA   69625581.0         Asia
# 39870    TH                  THA   69625581.0         Asia
# 39871    TH                  THA   69625581.0         Asia
# 39872    TH                  THA   69625581.0         Asia
# ...     ...                  ...          ...          ...
# 40123    TH                  THA   69625581.0         Asia
# 40124    TH                  THA   69625581.0         Asia
# 40125    TH                  THA   69625581.0         Asia
# 40126    TH                  THA   69625581.0         Asia
# 40127    TH                  THA   69625581.0         Asia
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 39868                                           0.093356
# 39869                                           0.087611
# 39870                                           0.089048
# 39871                                           0.099102
# 39872                                           0.094793
# ...                                                  ...
# 40123                                                NaN
# 40124                                                NaN
# 40125                                                NaN
# 40126                                                NaN
# 40127                                                NaN
#
# [260 rows x 12 columns]

# %%
alt.Chart(covid_th).mark_line().encode(
    x='dateRep',
    y='cases'
)
# Out:
# alt.Chart(...)
