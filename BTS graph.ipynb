# %%
import pandas as pd
import numpy as np
import altair as alt
bts = pd.read_excel("สายฉลองรัชธรรม.xlsx")
bts2 = pd.read_excel("สายเฉลิมรัชมงคล.xlsx")
bts.head()
# Out:
#        เดือน    ปี                              โครงการ  จำนวนผู้โดยสารรวม  \
# 0    สิงหาคม  2559  โครงการรถไฟฟ้ามหานคร สายฉลองรัชธรรม             532026
# 1    กันยายน  2559  โครงการรถไฟฟ้ามหานคร สายฉลองรัชธรรม             629963
# 2     ตุลาคม  2559  โครงการรถไฟฟ้ามหานคร สายฉลองรัชธรรม             650772
# 3  พฤศจิกายน  2559  โครงการรถไฟฟ้ามหานคร สายฉลองรัชธรรม             647337
# 4    ธันวาคม  2559  โครงการรถไฟฟ้ามหานคร สายฉลองรัชธรรม             614216
#
#    จำนวนผู้โดยสารเฉลี่ยรายวัน  จำนวนผู้โดยสารเฉลี่ยรายวันธรรมดา  \
# 0                       20172                             20492
# 1                       20999                             22658
# 2                       20993                             24212
# 3                       21578                             24238
# 4                       19161                             23048
#
#    จำนวนผู้โดยสารเฉลี่ยรายวันหยุด
# 0                           19568
# 1                           16437
# 2                           15140
# 3                           14264
# 4                           12093

# %%
alt.Chart(bts.reset_index()).mark_line().encode(
    x="index",
    y="จำนวนผู้โดยสารรวม"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(bts2.reset_index()).mark_line().encode(
    x="index",
    y="จำนวนผู้โดยสารรวม"
)
# Out:
# alt.Chart(...)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X = np.array(range(74)).reshape(-1, 1)
diabetes_y = bts2['จำนวนผู้โดยสารรวม']

# Use only one feature

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[0:74]
diabetes_X_test = diabetes_X[0:74]
# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[0:74]
diabetes_y_test = diabetes_y[0:74]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [46548.58610885]
# Mean squared error: 420867594543.02
# Coefficient of determination: 0.70

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X1 = np.array(range(74)).reshape(-1, 1)
diabetes_y = bts['จำนวนผู้โดยสารรวม']

# Use only one feature

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[0:43]
diabetes_X_test = diabetes_X[0:43]
# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[0:43]
diabetes_y_test = diabetes_y[0:43]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [30810.13349441]
# Mean squared error: 30770938784.23
# Coefficient of determination: 0.83
